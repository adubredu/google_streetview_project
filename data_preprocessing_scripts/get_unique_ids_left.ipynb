# %%
import pandas as pd

# %%
data = pd.read_csv('depressing.csv')

# %%
data.shape
# Out:
# (132467, 9)

# %%
data.head()
# Out:
#    Unnamed: 0                   left_id                  right_id winner  \
# 0           1  513d7e23fdc9f0358700733a  513d7ac3fdc9f0358700693f  equal
# 1           2  50f60c4dbeb2fed91000028d  513cb652fdc9f03587000a1e  right
# 2           3  513d9ff9fdc9f0358700887c  513cd544fdc9f03587001efc   left
# 3          12  5185cf07fdc9f03fd5000ebd  51422806fdc9f04926008700  equal
# 4          13  50f5e6fefdc9f065f0006eb2  513d6d7efdc9f0358700516c  equal
#
#     left_lat   left_long  right_lat  right_long    category
# 0  40.744156  -73.935579 -33.526384  -70.591309  depressing
# 1  45.505837 -122.583705  29.752872  -95.298844  depressing
# 2  33.747093  -84.289843 -33.930831   18.406321  depressing
# 3  45.562421  -73.539947  40.066826  -75.183961  depressing
# 4 -23.631807  -46.714255  39.754777 -104.871981  depressing

# %%
data.sort_values("left_id", inplace = True)

# %%
data.head(20)
# Out:
#         Unnamed: 0                   left_id                  right_id winner  \
# 43819       214805  50e5f7d4d7c3df413b00056d  51413ad8fdc9f049260057f3  equal
# 49984       246088  50e5f7d4d7c3df413b00056d  514219d8fdc9f049260082a8   left
# 128633     1045662  50e5f7d4d7c3df413b00056d  513d78dafdc9f035870062e7  right
# 54616       266523  50e5f7d4d7c3df413b00056d  50f61684beb2fed91000099e  right
# 79850       419989  50e5f7d4d7c3df413b00056e  50f607dabeb2fed6f8000317  equal
# 30287       147466  50e5f7d4d7c3df413b00056e  513cc900fdc9f03587001bc0   left
# 56312       274435  50e5f7d4d7c3df413b000570  513d9b94fdc9f03587007a63  right
# 1031          3378  50e5f7d4d7c3df413b000570  514227a0fdc9f0492600869f   left
# 64795       316094  50e5f7d4d7c3df413b000570  50f5644ffdc9f065f000626c   left
# 46128       228386  50e5f7d4d7c3df413b000570  513cccc6fdc9f03587001d55  right
# 29094       142331  50e5f7d4d7c3df413b000570  5140b7a9fdc9f04926001a7b   left
# ...

# %%
data.drop_duplicates(subset ="left_id", inplace = True)

# %%
data.shape
# Out:
# (76776, 9)

# %%
data.sort_values("left_id", inplace = True) 
data.head(20)
# Out:
#         Unnamed: 0                   left_id                  right_id winner  \
# 43819       214805  50e5f7d4d7c3df413b00056d  51413ad8fdc9f049260057f3  equal
# 79850       419989  50e5f7d4d7c3df413b00056e  50f607dabeb2fed6f8000317  equal
# 56312       274435  50e5f7d4d7c3df413b000570  513d9b94fdc9f03587007a63  right
# 6546         28674  50e5f7d5d7c3df413b000571  50f563fbfdc9f065f0005f92  right
# 16466        79424  50e5f7d5d7c3df413b000572  513cc356fdc9f03587001669  equal
# 31488       153205  50e5f7d5d7c3df413b000573  513d2ff0fdc9f035870026be   left
# 116737      694818  50e5f7d5d7c3df413b00057a  50f5e872fdc9f065f00072d2  right
# 127289      944360  50e5f7d6d7c3df413b00057c  50f42bb4fdc9f065f0001625   left
# 113581      662877  50e5f7d6d7c3df413b00057e  5140ce19fdc9f04926002ffe  right
# 117359      702947  50e5f7d6d7c3df413b000581  513d5c60fdc9f035870036df  equal
# 9973         46016  50e5f7d6d7c3df413b000582  51408928fdc9f0358700e461  right
# ...

# %%
data.to_csv('depressing_unique.csv')
