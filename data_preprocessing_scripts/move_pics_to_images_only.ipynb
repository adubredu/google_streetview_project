# %%
import os
import shutil

notfound = []
for filename in os.listdir("depressing_images_in_dir/"):
    try:
        shutil.copy2('depressing_images_in_dir/'+filename+'/gsv_0.jpg', 'images_only/'+filename+'.jpg')
    except:
        print(filename, 'not found')
        notfound.append(filename)
# Out:
# 513d38e2fdc9f03587002c86 not found
# 513d5c23fdc9f03587003676 not found
# 513d697efdc9f03587004756 not found
# 5140b9e3fdc9f04926001f30 not found
# 51408ab8fdc9f0358700e7a2 not found
# 513d61abfdc9f03587003e8e not found
# 513d356afdc9f03587002ad5 not found
# 513d3109fdc9f0358700279a not found
# 51409020fdc9f04926000220 not found
# 513d5c7afdc9f03587003717 not found
# 51409e08fdc9f049260013b1 not found
# 513d60e9fdc9f03587003d9c not found
# 5140cc27fdc9f04926002d26 not found
# 51408fc7fdc9f04926000170 not found
# 513d68a6fdc9f03587004450 not found
# 5140cbbdfdc9f04926002c38 not found
# 513f2d35fdc9f0358700d9c8 not found
# 513d4c06fdc9f03587002e23 not found
# 51408a62fdc9f0358700e6fb not found
# 5140b8affdc9f04926001cd0 not found
# 51408a52fdc9f0358700e6d4 not found
# 51409a4dfdc9f04926000f1f not found
# 5140cb4dfdc9f04926002af9 not found
# 513d5e11fdc9f035870039d8 not found
# 51409197fdc9f0492600053e not found
# 513d342afdc9f035870029ef not found
# 5140c8c0fdc9f04926002328 not found
# ...

# %%
len(notfound)
# Out:
# 24582

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.4MB 10.1MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# ...
# ERROR: matplotlib 2.2.2 requires cycler>=0.10, which is not installed.
# ERROR: matplotlib 2.2.2 requires kiwisolver>=1.0.1, which is not installed.
# ERROR: matplotlib 2.2.2 requires pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1, which is not installed.
# ...

# %%
import pandas as pd 
data = pd.read_csv('depressing.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-f06b449bfc76> in <module>
# ----> 1 import pandas as pd
#       2 data = pd.read_csv('depressing.csv')
#
# ImportError: No module named 'pandas'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-38d4b0363d82> in <module>
# ----> 1 import pandas
#
# ImportError: No module named 'pandas'

# %%
notfile = open('notavailable.txt', 'w')
for nav in notfound:
    notfile.write(nav)
